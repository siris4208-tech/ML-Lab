# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv('/content/placement_dataset.csv')

# %%
import os
os.listdir('/content/drive/MyDrive')
# Out:
# ['Colab Notebooks',
#  '2520030609.mp4',
#  '2520030609 Certification.docx',
#  'Classroom',
#  'Certificate of infosys.pdf',
#  '2520030609_V.Siri Chandana.pdf',
#  'Colab',
#  'Team -20.docx',
#  'TEAM - 20.pptx',
#  'SOCKETSERVERANDCLIENTPRACTICALPROBLEMS.gdoc',
#  'PRACTICAL5BAND5A.gdoc',
#  'SIGNAL PROGRAMS.gdoc']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages

sns.set_style("whitegrid")

# %%
df = pd.read_csv("placement_predict_50k Dataset (1).csv")

# %%
num_cols = ['CGPA','AttendancePercent', 'AptitudeTestScore','CodingTestScore', 'SoftSkillsRating','Salary Package']

# %%
fig1 = plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, cmap="Purples", yticklabels=False)
plt.title("Missingness Heatmap = Placement Prediction Dataset")
plt.xlabel("Columns")
plt.tight_layout()
plt.show()

# %%
fig2, axes = plt.subplots(2, 3, figsize=(15,8))

for i, col in enumerate(num_cols):
  row,colpos = divmod(i,3)
  sns.histplot(df[col].dropna(), bins=30,kde=True,
               ax = axes[row,colpos],color='steelblue')
  axes[row,colpos].set_title(f'Distribution of {col}')
plt.tight_layout()
plt.show()
